# %% [markdown]
# # Predicting winners for matches in premier league games
#
# ### Result predictions from multiple classifiers based on the match outcome from 21/22 and 22/23 season.

# %% [markdown]
# ### Imports
# Import all the required libraries including Pandas, numpy, matplotlib, and scikit learn.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# ML libraries
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_curve, auc
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Install Intel Extension for scikit-learn to speed up Scikit-learn application.

# %%
# !pip install scikit-learn-intelex
# !pip install dpcpp-cpp-rt
# Out:
# Requirement already satisfied: scikit-learn-intelex in /usr/local/lib/python3.10/dist-packages (2023.2.1)
# Requirement already satisfied: daal4py==2023.2.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-intelex) (2023.2.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-intelex) (1.2.2)
# Requirement already satisfied: daal==2023.2.1 in /usr/local/lib/python3.10/dist-packages (from daal4py==2023.2.1->scikit-learn-intelex) (2023.2.1)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from daal4py==2023.2.1->scikit-learn-intelex) (1.23.5)
# Requirement already satisfied: tbb==2021.* in /usr/local/lib/python3.10/dist-packages (from daal==2023.2.1->daal4py==2023.2.1->scikit-learn-intelex) (2021.10.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scikit-learn-intelex) (3.2.0)
# Requirement already satisfied: dpcpp-cpp-rt in /usr/local/lib/python3.10/dist-packages (2023.2.0)
# Requirement already satisfied: intel-opencl-rt==2023.2.0 in /usr/local/lib/python3.10/dist-packages (from dpcpp-cpp-rt) (2023.2.0)
# Requirement already satisfied: intel-openmp==2023.2.0 in /usr/local/lib/python3.10/dist-packages (from dpcpp-cpp-rt) (2023.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt==2023.2.0 in /usr/local/lib/python3.10/dist-packages (from dpcpp-cpp-rt) (2023.2.0)
# Requirement already satisfied: intel-cmplr-lic-rt==2023.2.0 in /usr/local/lib/python3.10/dist-packages (from dpcpp-cpp-rt) (2023.2.0)
# Requirement already satisfied: tbb==2021.* in /usr/local/lib/python3.10/dist-packages (from intel-opencl-rt==2023.2.0->dpcpp-cpp-rt) (2021.10.0)

# %% [markdown]
# ### Read csv
# As we have access to the csv file, we use pandas to read the dataset in the cell below.

# %%
url= 'https://raw.githubusercontent.com/Utsabab/Intel-oneAPI-Student-Ambassador/main/matches.csv'
mydata = pd.read_csv(url, index_col=0)

# %% [markdown]
# ### Dataset Shape
# In the cells below, we utilize the functions available as a part of pandas to display shape, first 100 data, and transpose the data. Pandas also lets us display the features in the dataset. These Pandas functions help us better understand the data.

# %%
mydata.shape
# Out:
# (1389, 27)

# %%
mydata.head(100)
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 37  2022-04-16  15:00  Premier League  Matchweek 33  Sat  Away      L  0.0
# 38  2022-04-20  19:45  Premier League  Matchweek 25  Wed  Away      W  4.0
# 39  2022-04-23  12:30  Premier League  Matchweek 34  Sat  Home      W  3.0
# 0   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Home      W  1.0
# 2   2021-08-22  14:00  Premier League   Matchweek 2  Sun  Away      W  1.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk  \
# 1   1.0        Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0
# 2   0.0     Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0
# 3   0.0          Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0
# 4   0.0   Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0
# 6   0.0      Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0
# ..  ...              ...  ...           ...    ...   ...   ...   ...  ...
# 37  1.0      Southampton  ...  Match Report    NaN  23.0   6.0  17.7  1.0
# 38  2.0          Chelsea  ...  Match Report    NaN  13.0   3.0  20.0  0.0
# 39  1.0   Manchester Utd  ...  Match Report    NaN  13.0   6.0  18.5  1.0
# 0   0.0  Manchester City  ...  Match Report    NaN  14.0   2.0  18.4  0.0
# 2   0.0           Wolves  ...  Match Report    NaN   7.0   5.0  14.3  0.0
#
#      pk pkatt  season               team
# 1   0.0   0.0    2022    Manchester City
# 2   0.0   0.0    2022    Manchester City
# 3   0.0   0.0    2022    Manchester City
# 4   0.0   0.0    2022    Manchester City
# 6   0.0   0.0    2022    Manchester City
# ..  ...   ...     ...                ...
# 37  0.0   0.0    2022            Arsenal
# 38  1.0   1.0    2022            Arsenal
# 39  1.0   1.0    2022            Arsenal
# 0   0.0   0.0    2022  Tottenham Hotspur
# 2   1.0   1.0    2022  Tottenham Hotspur
#
# [100 rows x 27 columns]

# %%
mydata.head().T
# Out:
#                             1                2                3  \
# date               2021-08-15       2021-08-21       2021-08-28
# time                    16:30            15:00            12:30
# comp           Premier League   Premier League   Premier League
# round             Matchweek 1      Matchweek 2      Matchweek 3
# day                       Sun              Sat              Sat
# venue                    Away             Home             Home
# result                      L                W                W
# gf                        0.0              5.0              5.0
# ga                        1.0              0.0              0.0
# opponent            Tottenham     Norwich City          Arsenal
# xg                        1.9              2.7              3.8
# xga                       1.3              0.1              0.1
# poss                     64.0             67.0             80.0
# attendance            58262.0          51437.0          52276.0
# captain           Fernandinho   İlkay Gündoğan   İlkay Gündoğan
# formation               4-3-3            4-3-3            4-3-3
# referee        Anthony Taylor     Graham Scott  Martin Atkinson
# match report     Match Report     Match Report     Match Report
# notes                     NaN              NaN              NaN
# sh                       18.0             16.0             25.0
# sot                       4.0              4.0             10.0
# dist                     16.9             17.3             14.3
# fk                        1.0              1.0              0.0
# pk                        0.0              0.0              0.0
# pkatt                     0.0              0.0              0.0
# season                   2022             2022             2022
# team          Manchester City  Manchester City  Manchester City
#
#                             4                6
# date               2021-09-11       2021-09-18
# time                    15:00            15:00
# comp           Premier League   Premier League
# round             Matchweek 4      Matchweek 5
# day                       Sat              Sat
# venue                    Away             Home
# result                      W                D
# gf                        1.0              0.0
# ga                        0.0              0.0
# opponent       Leicester City      Southampton
# xg                        2.9              1.1
# xga                       0.8              0.4
# poss                     61.0             63.0
# attendance            32087.0          52698.0
# captain        İlkay Gündoğan      Fernandinho
# formation               4-3-3            4-3-3
# referee          Paul Tierney    Jonathan Moss
# match report     Match Report     Match Report
# notes                     NaN              NaN
# sh                       25.0             16.0
# sot                       8.0              1.0
# dist                     14.0             15.7
# fk                        0.0              1.0
# pk                        0.0              0.0
# pkatt                     0.0              0.0
# season                   2022             2022
# team          Manchester City  Manchester City

# %%
mydata.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team'],
#       dtype='object')

# %% [markdown]
# ### Every team plays a total of 38 matches in a season. We have data from the last 2 seasons. Most of the team has data of more than 70 matches played. However, some teams have number of matches in the range of 30.

# %%
mydata["team"].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %% [markdown]
# ### 3 teams get relegated from EPL every season and 3 different team gets promoted the next season. Therefore, 6 teams will have matches played in the range of 30. Liverpool is the only team where we have data from season 21/22 only although it played both of the last 2 seasons.

# %%
mydata[mydata["team"] == "Liverpool"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# 20  2020-12-13  16:30  Premier League  Matchweek 12  Sun  Away      D  1.0
# 21  2020-12-16  20:00  Premier League  Matchweek 13  Wed  Home      W  2.0
# 22  2020-12-19  12:30  Premier League  Matchweek 14  Sat  Away      W  7.0
# 23  2020-12-27  16:30  Premier League  Matchweek 15  Sun  Home      D  1.0
# 24  2020-12-30  20:00  Premier League  Matchweek 16  Wed  Away      D  0.0
# 25  2021-01-04  20:00  Premier League  Matchweek 17  Mon  Away      L  0.0
# 27  2021-01-17  16:30  Premier League  Matchweek 19  Sun  Home      D  0.0
# 28  2021-01-21  20:00  Premier League  Matchweek 18  Thu  Home      L  0.0
# 30  2021-01-28  20:00  Premier League  Matchweek 20  Thu  Away      W  3.0
# 31  2021-01-31  16:30  Premier League  Matchweek 21  Sun  Away      W  3.0
# 32  2021-02-03  20:15  Premier League  Matchweek 22  Wed  Home      L  0.0
# 33  2021-02-07  16:30  Premier League  Matchweek 23  Sun  Home      L  1.0
# 34  2021-02-13  12:30  Premier League  Matchweek 24  Sat  Away      L  1.0
# 36  2021-02-20  17:30  Premier League  Matchweek 25  Sat  Home      L  0.0
# 37  2021-02-28  19:15  Premier League  Matchweek 26  Sun  Away      W  2.0
# 38  2021-03-04  20:15  Premier League  Matchweek 29  Thu  Home      L  0.0
# 39  2021-03-07  14:00  Premier League  Matchweek 27  Sun  Home      L  0.0
# 41  2021-03-15  20:00  Premier League  Matchweek 28  Mon  Away      W  1.0
# 42  2021-04-03  20:00  Premier League  Matchweek 30  Sat  Away      W  3.0
# 44  2021-04-10  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 46  2021-04-19  20:00  Premier League  Matchweek 32  Mon  Away      D  1.0
# 47  2021-04-24  12:30  Premier League  Matchweek 33  Sat  Home      D  1.0
# 48  2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W  2.0
# 49  2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W  4.0
# 50  2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W  2.0
# 51  2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W  3.0
# 52  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk  \
# 1   3.0     Leeds United  ...  Match Report    NaN  20.0   4.0  17.0  0.0
# 2   0.0          Chelsea  ...  Match Report    NaN  17.0   5.0  17.7  1.0
# 4   1.0          Arsenal  ...  Match Report    NaN  21.0   9.0  16.8  0.0
# 6   7.0      Aston Villa  ...  Match Report    NaN  14.0   8.0  15.8  1.0
# 7   2.0          Everton  ...  Match Report    NaN  22.0   8.0  15.0  1.0
# 9   1.0    Sheffield Utd  ...  Match Report    NaN  17.0   5.0  18.2  1.0
# 11  1.0         West Ham  ...  Match Report    NaN   8.0   2.0  18.6  1.0
# 13  1.0  Manchester City  ...  Match Report    NaN   9.0   2.0  21.5  0.0
# 14  0.0   Leicester City  ...  Match Report    NaN  24.0  12.0  11.9  0.0
# 16  1.0         Brighton  ...  Match Report    NaN   6.0   2.0  20.9  0.0
# 18  0.0           Wolves  ...  Match Report    NaN  11.0   6.0  16.6  1.0
# 20  1.0           Fulham  ...  Match Report    NaN  11.0   5.0  20.0  1.0
# 21  1.0        Tottenham  ...  Match Report    NaN  17.0  11.0  15.5  0.0
# 22  0.0   Crystal Palace  ...  Match Report    NaN  14.0   7.0  13.2  1.0
# 23  1.0        West Brom  ...  Match Report    NaN  17.0   2.0  17.8  2.0
# 24  0.0    Newcastle Utd  ...  Match Report    NaN  11.0   4.0  16.7  0.0
# 25  1.0      Southampton  ...  Match Report    NaN  17.0   1.0  14.3  0.0
# 27  0.0   Manchester Utd  ...  Match Report    NaN  17.0   3.0  17.1  0.0
# 28  1.0          Burnley  ...  Match Report    NaN  27.0   6.0  17.3  0.0
# 30  1.0        Tottenham  ...  Match Report    NaN  14.0   7.0  14.7  0.0
# 31  1.0         West Ham  ...  Match Report    NaN  14.0   5.0  15.3  0.0
# 32  1.0         Brighton  ...  Match Report    NaN  11.0   0.0  19.9  0.0
# 33  4.0  Manchester City  ...  Match Report    NaN   7.0   2.0  17.9  1.0
# 34  3.0   Leicester City  ...  Match Report    NaN  15.0   4.0  15.4  2.0
# 36  2.0          Everton  ...  Match Report    NaN  16.0   6.0  15.9  1.0
# 37  0.0    Sheffield Utd  ...  Match Report    NaN  15.0   8.0  14.2  0.0
# 38  1.0          Chelsea  ...  Match Report    NaN   7.0   1.0  18.4  0.0
# 39  1.0           Fulham  ...  Match Report    NaN  16.0   3.0  17.0  1.0
# 41  0.0           Wolves  ...  Match Report    NaN  12.0   4.0  15.9  0.0
# 42  0.0          Arsenal  ...  Match Report    NaN  16.0   7.0  17.0  0.0
# 44  1.0      Aston Villa  ...  Match Report    NaN  23.0   8.0  16.7  1.0
# 46  1.0     Leeds United  ...  Match Report    NaN  17.0   7.0  15.7  0.0
# 47  1.0    Newcastle Utd  ...  Match Report    NaN  21.0   9.0  17.0  1.0
# 48  0.0      Southampton  ...  Match Report    NaN  14.0   6.0  12.4  0.0
# 49  2.0   Manchester Utd  ...  Match Report    NaN  17.0   8.0  14.9  0.0
# 50  1.0        West Brom  ...  Match Report    NaN  26.0   6.0  16.9  1.0
# 51  0.0          Burnley  ...  Match Report    NaN  20.0   3.0  15.5  1.0
# 52  0.0   Crystal Palace  ...  Match Report    NaN  19.0   5.0  14.2  1.0
#
#      pk pkatt  season       team
# 1   2.0   2.0    2021  Liverpool
# 2   0.0   0.0    2021  Liverpool
# 4   0.0   0.0    2021  Liverpool
# 6   0.0   0.0    2021  Liverpool
# 7   0.0   0.0    2021  Liverpool
# 9   0.0   0.0    2021  Liverpool
# 11  1.0   1.0    2021  Liverpool
# 13  1.0   1.0    2021  Liverpool
# 14  0.0   0.0    2021  Liverpool
# 16  0.0   0.0    2021  Liverpool
# 18  0.0   0.0    2021  Liverpool
# 20  1.0   1.0    2021  Liverpool
# 21  0.0   0.0    2021  Liverpool
# 22  0.0   0.0    2021  Liverpool
# 23  0.0   0.0    2021  Liverpool
# 24  0.0   0.0    2021  Liverpool
# 25  0.0   0.0    2021  Liverpool
# 27  0.0   0.0    2021  Liverpool
# 28  0.0   0.0    2021  Liverpool
# 30  0.0   0.0    2021  Liverpool
# 31  0.0   0.0    2021  Liverpool
# 32  0.0   0.0    2021  Liverpool
# 33  1.0   1.0    2021  Liverpool
# 34  0.0   0.0    2021  Liverpool
# 36  0.0   0.0    2021  Liverpool
# 37  0.0   0.0    2021  Liverpool
# 38  0.0   0.0    2021  Liverpool
# 39  0.0   0.0    2021  Liverpool
# 41  0.0   0.0    2021  Liverpool
# 42  0.0   0.0    2021  Liverpool
# 44  0.0   0.0    2021  Liverpool
# 46  0.0   0.0    2021  Liverpool
# 47  0.0   0.0    2021  Liverpool
# 48  0.0   0.0    2021  Liverpool
# 49  0.0   0.0    2021  Liverpool
# 50  0.0   0.0    2021  Liverpool
# 51  0.0   0.0    2021  Liverpool
# 52  0.0   0.0    2021  Liverpool
#
# [38 rows x 27 columns]

# %%
mydata.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %% [markdown]
# ### Convert date to datetime dtype

# %%
mydata["date"] = pd.to_datetime(mydata["date"])

# %% [markdown]
# ### Identify missing values
# As we preprocess the data, it is necessary for us to identify the features which have missing values in between. Below we create a count of missing values in each features of the dataset.
#
# The plot display shows the number of data missing in each of the dataset feature.

# %%
def print_missing_values(data):
    data_null = pd.DataFrame(len(data) - data.notnull().sum(), columns = ['Count'])
    data_null = data_null[data_null['Count'] > 0].sort_values('Count', ascending=False)
    data_null = data_null/len(data)*100 #percentage
    data_null.reset_index(inplace=True)
    data_null = data_null.rename(columns = {'index':'Features'})

    plt.style.use('ggplot')
    x = data_null['Features']
    y = data_null['Count']
    x_pos = [i for i, _ in enumerate(x)]

    plt.figure(figsize=(4,4))
    plt.bar(x_pos, y, color='green')
    plt.xlabel('Features')
    plt.ylabel('Percentage of missing data')
    plt.title("Column with missing values in the dataset")

    plt.xticks(x_pos, x)
    plt.show()

# %%
print('Number total of rows : '+ str(mydata.shape[0]))
print_missing_values(mydata)
# Out:
# Number total of rows : 1389

# %% [markdown]
# ### Drop 'match report' and 'notes' feature as it does not provide any insight for the predictor.

# %%
mydata.drop(['notes', 'match report'], axis=1, inplace=True)

# %% [markdown]
# ## Categorize data into Categorical and Numerical values

# %%
def categorize(data):
  num_columns = []
  cat_columns = []

  for col in data.columns.values:
      if data[col].dtypes == 'int64' or data[col].dtypes == 'float64':
          num_columns += [col]
      else:
          cat_columns += [col]
  return [cat_columns, num_columns]

# %%
cat_val, num_val = categorize(mydata)

# %% [markdown]
# ## Median value
# For each of the numerical feature, find the median value and save it as median value of the fearure.

# %%
median_val = pd.Series()
for col in num_val:
    median_val[col] = mydata[col].median()
print("Median values for each Numerical features \n\n", median_val)
# Out:
# Median values for each Numerical features
#
#  gf                1.0
# ga                1.0
# xg                1.2
# xga               1.2
# poss             50.0
# attendance    32061.0
# sh               12.0
# sot               4.0
# dist             16.9
# fk                0.0
# pk                0.0
# pkatt             0.0
# season         2021.0
# dtype: float64

# %% [markdown]
# ## Handle missing values
# As couple of features have missing data in it, these missing values should be replaced before we can train the model. These missing values are replaced by median value generated in the previous code for numerical features. Missing values for categorical features should be replaced by "Missing value".

# %%
def handle_missing_values(data, median_val):
    df = data.copy()
    for col in df:
        if col in median_val.index.values:
            df[col] = df[col].fillna(median_val[col])
        else:
            df[col] = df[col].fillna("Missing value")

    return df

# %%
mydata = handle_missing_values(mydata, median_val)

# %% [markdown]
# ## Data distribution based on target label

# %%
def target_distribution(y_var, data):
    val = data[y_var]

    plt.style.use('seaborn-whitegrid')
    plt.rcParams.update({'font.size': 13})
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

    cnt = val.value_counts().sort_values(ascending=True)
    labels = cnt.index.values

    sizes = cnt.values
    colors = sns.color_palette("PuBu", len(labels))

    # print(cnt)
    # print(labels)
    # print(sizes)

    #------------COUNT-----------------------
    ax1.barh(cnt.index.values, cnt.values, color=colors)
    ax1.set_title('Count plot of '+y_var)

    #------------PERCENTAGE-------------------
    ax2.pie(sizes, labels=labels, colors=colors,autopct='%1.0f%%', shadow=True, startangle=130)
    ax2.axis('equal')
    ax2.set_title('Distribution of '+y_var)
    plt.show()

# %%
var = 'result'
target_distribution(y_var=var, data=mydata)

# %% [markdown]
# ## Label Encode
# Categorical variables are not readable to ML algorithms. Hence, it is necessary to convert them into integer based binary format.

# %%
from sklearn.preprocessing import MultiLabelBinarizer

def label_encode(data, categorical_features):
  data_encoded = data.copy()
  categorical_names = {}

# Use Label Encoder for categorical columns
  for feature in categorical_features:
      le = LabelEncoder()
      le.fit(data_encoded[feature])
      data_encoded[feature] = le.fit_transform(data_encoded[feature])
      if feature == 'result':
        categorical_names[feature] = le.classes_
        le_name_mapping = dict(zip(le.transform(le.classes_), le.classes_))

  return (data_encoded, categorical_names, le_name_mapping)

# %%
mydata
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  formation          referee    sh   sot  dist  \
# 1   1.0       Tottenham  ...      4-3-3   Anthony Taylor  18.0   4.0  16.9
# 2   0.0    Norwich City  ...      4-3-3     Graham Scott  16.0   4.0  17.3
# 3   0.0         Arsenal  ...      4-3-3  Martin Atkinson  25.0  10.0  14.3
# 4   0.0  Leicester City  ...      4-3-3     Paul Tierney  25.0   8.0  14.0
# 6   0.0     Southampton  ...      4-3-3    Jonathan Moss  16.0   1.0  15.7
# ..  ...             ...  ...        ...              ...   ...   ...   ...
# 38  4.0       Tottenham  ...    3-4-1-2   Andre Marriner   8.0   1.0  17.4
# 39  2.0  Crystal Palace  ...      3-5-2     Simon Hooper   7.0   0.0  11.4
# 40  0.0         Everton  ...      3-4-3    Jonathan Moss  10.0   3.0  17.0
# 41  1.0   Newcastle Utd  ...      3-4-3     Robert Jones  11.0   1.0  16.0
# 42  0.0         Burnley  ...      3-4-3     Kevin Friend  12.0   3.0  17.0
#
#      fk   pk  pkatt  season              team
# 1   1.0  0.0    0.0    2022   Manchester City
# 2   1.0  0.0    0.0    2022   Manchester City
# 3   0.0  0.0    0.0    2022   Manchester City
# 4   0.0  0.0    0.0    2022   Manchester City
# 6   1.0  0.0    0.0    2022   Manchester City
# ..  ...  ...    ...     ...               ...
# 38  0.0  0.0    0.0    2021  Sheffield United
# 39  1.0  0.0    0.0    2021  Sheffield United
# 40  0.0  0.0    0.0    2021  Sheffield United
# 41  1.0  0.0    0.0    2021  Sheffield United
# 42  0.0  0.0    0.0    2021  Sheffield United
#
# [1389 rows x 25 columns]

# %% [markdown]
# ## Feature Scaling
# Data normalization is important in Machine learning as it is used to standardize the range of features of data. We transform the data such that the numericalfeatures are within a specific range [0,1].

# %%
def scale_data(data, numerical_features):
  data_encoded = data.copy()
  for feature in numerical_features:
      val = data_encoded[feature].values[:, np.newaxis]
      mms = MinMaxScaler()
      data_encoded[feature] = mms.fit_transform(val)

  data_encoded = data_encoded.astype(float)
  return data_encoded

# %% [markdown]
# ## Preprocess data
# Categorize, label encode and normalize the data.

# %%
data_category = categorize(mydata)
categorical_features, numerical_features = data_category[0], data_category[1]

mydata, result_map, name_mapping = label_encode(mydata, categorical_features)
mydata = scale_data(mydata, numerical_features)

# %%
print(name_mapping)
# Out:
# {0: 'D', 1: 'L', 2: 'W'}

# %%
mydata.head(50)
# Out:
#      date  time  comp  round  day  venue  result        gf        ga  \
# 1   137.0   8.0   0.0    0.0  3.0    0.0     1.0  0.000000  0.111111
# 2   138.0   6.0   0.0   11.0  2.0    1.0     2.0  0.555556  0.000000
# 3   141.0   1.0   0.0   22.0  2.0    1.0     2.0  0.555556  0.000000
# 4   143.0   6.0   0.0   32.0  2.0    0.0     2.0  0.111111  0.000000
# 6   147.0   6.0   0.0   33.0  2.0    1.0     0.0  0.000000  0.000000
# 8   149.0   1.0   0.0   34.0  2.0    0.0     2.0  0.111111  0.000000
# 10  153.0   8.0   0.0   35.0  3.0    0.0     0.0  0.222222  0.222222
# 11  154.0   6.0   0.0   36.0  2.0    1.0     2.0  0.222222  0.000000
# 13  158.0   9.0   0.0   37.0  2.0    0.0     2.0  0.444444  0.111111
# 15  160.0   6.0   0.0    1.0  2.0    1.0     1.0  0.000000  0.222222
# 17  164.0   1.0   0.0    2.0  2.0    0.0     2.0  0.222222  0.000000
# 18  167.0   3.0   0.0    3.0  3.0    1.0     2.0  0.333333  0.000000
# 20  169.0   3.0   0.0    4.0  3.0    1.0     2.0  0.222222  0.111111
# 21  171.0  17.0   0.0    5.0  6.0    0.0     2.0  0.222222  0.111111
# 22  173.0   9.0   0.0    6.0  2.0    0.0     2.0  0.333333  0.111111
# 24  177.0   1.0   0.0    7.0  2.0    1.0     2.0  0.111111  0.000000
# 25  179.0  16.0   0.0    8.0  5.0    1.0     2.0  0.777778  0.000000
# 26  183.0   5.0   0.0    9.0  3.0    0.0     2.0  0.444444  0.000000
# 27  184.0   6.0   0.0   10.0  3.0    1.0     2.0  0.666667  0.333333
# 28  187.0  17.0   0.0   12.0  6.0    0.0     2.0  0.111111  0.000000
# 29  189.0   1.0   0.0   13.0  2.0    0.0     2.0  0.222222  0.111111
# 31  195.0   1.0   0.0   14.0  2.0    1.0     2.0  0.111111  0.000000
# 32  200.0   9.0   0.0   15.0  2.0    0.0     0.0  0.111111  0.111111
# 34  204.0  15.0   0.0   16.0  6.0    1.0     2.0  0.222222  0.000000
# 35  206.0   9.0   0.0   17.0  2.0    0.0     2.0  0.444444  0.000000
# 37  209.0   9.0   0.0   18.0  2.0    1.0     1.0  0.222222  0.333333
# 38  214.0   9.0   0.0   19.0  2.0    0.0     2.0  0.111111  0.000000
# 40  218.0   8.0   0.0   20.0  3.0    1.0     2.0  0.444444  0.111111
# 42  223.0  16.0   0.0   21.0  1.0    0.0     0.0  0.000000  0.000000
# 44  229.0   6.0   0.0   24.0  2.0    0.0     2.0  0.222222  0.000000
# 46  235.0   8.0   0.0   25.0  3.0    1.0     0.0  0.222222  0.222222
# 49  239.0  16.0   0.0   23.0  6.0    1.0     2.0  0.333333  0.000000
# 50  241.0   6.0   0.0   27.0  2.0    1.0     2.0  0.555556  0.111111
# 1   136.0   6.0   0.0    0.0  2.0    1.0     2.0  0.333333  0.000000
# 2   139.0   8.0   0.0   11.0  3.0    0.0     2.0  0.222222  0.000000
# 3   141.0   9.0   0.0   22.0  2.0    0.0     0.0  0.111111  0.111111
# 4   143.0   9.0   0.0   32.0  2.0    1.0     2.0  0.333333  0.000000
# 6   148.0   8.0   0.0   33.0  3.0    0.0     2.0  0.333333  0.000000
# 8   149.0   1.0   0.0   34.0  2.0    1.0     1.0  0.000000  0.111111
# 10  152.0   6.0   0.0   35.0  2.0    1.0     2.0  0.333333  0.111111
# 11  154.0   9.0   0.0   36.0  2.0    0.0     2.0  0.111111  0.000000
# 13  158.0   1.0   0.0   37.0  2.0    1.0     2.0  0.777778  0.000000
# 15  160.0   6.0   0.0    1.0  2.0    0.0     2.0  0.333333  0.000000
# 17  164.0   6.0   0.0    2.0  2.0    1.0     0.0  0.111111  0.111111
# 18  166.0   1.0   0.0    3.0  2.0    0.0     2.0  0.333333  0.000000
# 20  169.0   8.0   0.0    4.0  3.0    1.0     0.0  0.111111  0.111111
# 21  171.0  14.0   0.0    5.0  6.0    0.0     2.0  0.222222  0.111111
# 22  173.0   1.0   0.0    6.0  2.0    0.0     1.0  0.222222  0.333333
# 24  177.0   6.0   0.0    7.0  2.0    1.0     2.0  0.333333  0.222222
# 25  181.0  15.0   0.0    8.0  4.0    1.0     0.0  0.111111  0.111111
#
#     opponent  ...  formation  referee        sh       sot      dist    fk  \
# 1       18.0  ...       10.0      2.0  0.580645  0.266667  0.417476  0.25
# 2       15.0  ...       10.0      7.0  0.516129  0.266667  0.430421  0.25
# 3        0.0  ...       10.0     13.0  0.806452  0.666667  0.333333  0.00
# 4       10.0  ...       10.0     17.0  0.806452  0.533333  0.323625  0.00
# 6       17.0  ...       10.0     10.0  0.516129  0.066667  0.378641  0.25
# 8        5.0  ...       10.0     14.0  0.483871  0.200000  0.404531  0.00
# 10      11.0  ...       10.0     17.0  0.387097  0.200000  0.414239  0.25
# 11       4.0  ...       10.0     13.0  0.516129  0.400000  0.343042  0.00
# 13       3.0  ...       10.0     11.0  0.741935  0.866667  0.378641  0.25
# 15       6.0  ...       10.0      0.0  0.451613  0.200000  0.420712  0.00
# 17      13.0  ...       10.0     14.0  0.516129  0.333333  0.343042  0.00
# 18       7.0  ...       10.0     21.0  0.548387  0.466667  0.368932  0.25
# 20      21.0  ...       10.0     14.0  0.612903  0.533333  0.349515  0.00
# 21       1.0  ...        7.0     16.0  0.548387  0.466667  0.485437  0.25
# 22      19.0  ...       10.0     20.0  0.838710  0.800000  0.323625  0.00
# 24      22.0  ...       10.0     10.0  0.741935  0.533333  0.362460  0.00
# 25       9.0  ...       10.0     17.0  1.000000  1.000000  0.394822  0.50
# 26      14.0  ...       10.0     13.0  0.580645  0.466667  0.252427  0.00
# 27      10.0  ...       10.0      3.0  0.483871  0.400000  0.407767  0.25
# 28       2.0  ...       10.0      6.0  0.387097  0.266667  0.475728  0.00
# 29       0.0  ...       10.0     21.0  0.451613  0.066667  0.466019  0.00
# 31       5.0  ...       10.0      4.0  0.354839  0.400000  0.411003  0.25
# 32      17.0  ...       10.0     20.0  0.645161  0.333333  0.404531  0.00
# 34       2.0  ...       10.0      5.0  0.451613  0.400000  0.478964  0.00
# 35      15.0  ...       10.0      0.0  0.677419  0.533333  0.245955  0.00
# 37      18.0  ...       10.0      2.0  0.645161  0.200000  0.375405  0.00
# 38       7.0  ...       10.0     17.0  0.419355  0.533333  0.378641  0.00
# 40      13.0  ...       10.0     14.0  0.774194  0.666667  0.349515  0.25
# 42       6.0  ...       10.0     13.0  0.580645  0.266667  0.436893  0.00
# 44       4.0  ...       10.0      4.0  0.580645  0.400000  0.391586  0.00
# 46      11.0  ...        7.0      2.0  0.354839  0.266667  0.404531  0.25
# 49       3.0  ...       10.0     16.0  0.548387  0.333333  0.485437  0.00
# 50      19.0  ...        7.0     11.0  0.645161  0.466667  0.346278  0.00
# 1        6.0  ...        1.0     10.0  0.419355  0.400000  0.543689  1.00
# 2        0.0  ...        1.0     17.0  0.709677  0.333333  0.343042  0.00
# 3       11.0  ...        1.0      2.0  0.193548  0.133333  0.268608  0.00
# 4        1.0  ...        1.0     21.0  0.387097  0.266667  0.598706  0.00
# 6       18.0  ...        1.0     17.0  0.645161  0.600000  0.297735  0.00
# 8       12.0  ...        4.0     14.0  0.161290  0.000000  0.818770  0.25
# 10      17.0  ...        1.0     13.0  0.645161  0.600000  0.297735  0.00
# 11       2.0  ...        4.0      2.0  0.161290  0.066667  0.624595  0.50
# 13      15.0  ...        1.0      1.0  0.709677  0.800000  0.511327  0.00
# 15      14.0  ...        1.0     17.0  0.580645  0.333333  0.511327  0.25
# 17       4.0  ...        0.0      0.0  0.806452  0.266667  0.352751  0.00
# 18      10.0  ...        1.0     17.0  0.516129  0.466667  0.378641  0.50
# 20      13.0  ...        1.0      2.0  0.741935  0.333333  0.388350  0.00
# 21      19.0  ...        1.0      6.0  0.258065  0.266667  0.336570  0.00
# 22      21.0  ...        1.0      0.0  0.612903  0.466667  0.414239  0.00
# 24       9.0  ...        1.0      3.0  0.451613  0.266667  0.533981  0.50
# 25       7.0  ...        1.0     14.0  0.741935  0.666667  0.349515  0.50
#
#           pk     pkatt  season  team
# 1   0.000000  0.000000     1.0  12.0
# 2   0.000000  0.000000     1.0  12.0
# 3   0.000000  0.000000     1.0  12.0
# 4   0.000000  0.000000     1.0  12.0
# 6   0.000000  0.000000     1.0  12.0
# 8   0.000000  0.000000     1.0  12.0
# 10  0.000000  0.000000     1.0  12.0
# 11  0.000000  0.000000     1.0  12.0
# 13  0.000000  0.000000     1.0  12.0
# 15  0.000000  0.000000     1.0  12.0
# 17  0.000000  0.000000     1.0  12.0
# 18  0.000000  0.000000     1.0  12.0
# 20  0.000000  0.000000     1.0  12.0
# 21  0.000000  0.000000     1.0  12.0
# 22  0.000000  0.000000     1.0  12.0
# 24  0.333333  0.333333     1.0  12.0
# 25  0.000000  0.000000     1.0  12.0
# 26  0.000000  0.000000     1.0  12.0
# 27  0.666667  0.666667     1.0  12.0
# 28  0.000000  0.000000     1.0  12.0
# 29  0.333333  0.333333     1.0  12.0
# 31  0.000000  0.000000     1.0  12.0
# 32  0.000000  0.000000     1.0  12.0
# 34  0.333333  0.333333     1.0  12.0
# 35  0.000000  0.333333     1.0  12.0
# 37  0.333333  0.333333     1.0  12.0
# 38  0.000000  0.000000     1.0  12.0
# 40  0.000000  0.000000     1.0  12.0
# 42  0.000000  0.000000     1.0  12.0
# 44  0.000000  0.000000     1.0  12.0
# 46  0.000000  0.000000     1.0  12.0
# 49  0.000000  0.000000     1.0  12.0
# 50  0.333333  0.333333     1.0  12.0
# 1   0.000000  0.000000     1.0   5.0
# 2   0.000000  0.000000     1.0   5.0
# 3   0.000000  0.000000     1.0   5.0
# 4   0.000000  0.000000     1.0   5.0
# 6   0.000000  0.000000     1.0   5.0
# 8   0.000000  0.000000     1.0   5.0
# 10  0.000000  0.000000     1.0   5.0
# 11  0.000000  0.000000     1.0   5.0
# 13  0.333333  0.333333     1.0   5.0
# 15  0.333333  0.333333     1.0   5.0
# 17  0.000000  0.000000     1.0   5.0
# 18  0.000000  0.000000     1.0   5.0
# 20  0.333333  0.333333     1.0   5.0
# 21  0.000000  0.000000     1.0   5.0
# 22  0.000000  0.000000     1.0   5.0
# 24  0.666667  0.666667     1.0   5.0
# 25  0.000000  0.000000     1.0   5.0
#
# [50 rows x 25 columns]

# %%
# sns.pairplot(mydata, hue='FTR')
# plt.show()

# %% [markdown]
# ## Split data into train and test

# %%
train_data, test_data = train_test_split(mydata, test_size=0.3, random_state=42)
train_data = train_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

# %% [markdown]
# ## Bar graph

# %%
def count_df(df, var):
  ftr = df[var].tolist()
  count = df['Count'].tolist()
  fig = plt.figure(figsize = (10, 5))
  ax = fig.add_axes([0,0,1,1])
  colors = sns.color_palette("PuBu", len(count))
  ax.bar(ftr, count, color=colors, width=0.4)
  ax.set_ylabel('Count')
  ax.set_xlabel(var)
  plt.show()

# %%
nm = train_data['result'].value_counts().rename_axis('result').reset_index(name='Count')
nm.result.replace([2.0, 1.0, 0.0], ['Win', 'Loss', 'Draw'], inplace=True)
count_df(nm, 'result')

# %%
from matplotlib import pyplot
from collections import Counter

def data_balance_visual(y):
  ftr = []
  counter = Counter(y)
  print(counter)
  for c in counter.keys():
    if c == 2.0:
      ftr.append('Win')
    elif c == 1.0:
        ftr.append('Loss')
    else:
      ftr.append('Draw')

  pyplot.figure(figsize=(8,7))
  pyplot.bar(ftr, counter.values(), color="steelblue")
  pyplot.show()

# %% [markdown]
# ## SMOTE to balance target label and avoid overfitting

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

def data_SMOTE(df, col):
  features_SMOTE = df.drop(col, axis=1)
  labels_SMOTE = df[col]
  labels_SMOTE = pd.DataFrame(labels_SMOTE)

  X_SMOTE = features_SMOTE.to_numpy()
  y_SMOTE = labels_SMOTE.to_numpy()

  #flatten numpy array with nested list [[1.], [1.], [1.]]
  flatList = [ item for elem in y_SMOTE for item in elem]
  flatList = np.asarray(flatList)
  data_balance_visual(flatList)

  sampl_s = {0.0:372}
  over = SMOTE(sampling_strategy = sampl_s, random_state=42)

  X_SMOTE, y_SMOTE = over.fit_resample(X_SMOTE, y_SMOTE)
  print(y_SMOTE)

  data_balance_visual(y_SMOTE)
  X_SMOTE = pd.DataFrame(X_SMOTE, columns=features_SMOTE.columns)
  y_SMOTE = pd.DataFrame(y_SMOTE, columns=labels_SMOTE.columns)
  balanced_data = pd.concat([X_SMOTE, y_SMOTE], axis=1, join="inner")

  # counter = Counter(y_SMOTE)
  return balanced_data

# %% [markdown]
# ## Balance target label to feed ML algorithm enough data on all classes of target.

# %%
train_data = data_SMOTE(train_data, 'result')
# Out:
# Counter({1.0: 379, 2.0: 376, 0.0: 217})
# [0. 2. 0. ... 0. 0. 0.]
# Counter({1.0: 379, 2.0: 376, 0.0: 372})

# %% [markdown]
# ## Split into features and label.

# %%
X_train = train_data.drop('result', axis=1)
y_train = train_data['result']

X_test = test_data.drop('result', axis=1).reset_index(drop=True)
y_test = test_data['result'].reset_index(drop=True)

# %% [markdown]
# ## Function to calculate accuracy of classifier

# %%
def accuracy(y_true, y_pred):

    """
    Function to calculate accuracy
    -> param y_true: list of true values
    -> param y_pred: list of predicted values
    -> return: accuracy score

    """

    # Intitializing variable to store count of correctly predicted classes
    correct_predictions = 0

    for yt, yp in zip(y_true, y_pred):

        if yt == yp:

            correct_predictions += 1

    #returns accuracy
    return correct_predictions / len(y_true)

# %% [markdown]
# ## Naive Bayes Classifier

# %%
from sklearnex import patch_sklearn
patch_sklearn()

from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB().fit(X_train, y_train)
y_pred = gnb.predict(X_test)

labels = [0.0,1.0,2.0]
cm = confusion_matrix(y_test, y_pred, labels=labels)
conf_mat = pd.DataFrame(cm,
                        columns=['Draw','Loss','Win'],
                        index=['Draw','Loss','Win'])

print(conf_mat)
nv_accuracy = accuracy(y_test, y_pred)
print("Accuracy of Decision Tree Model is: "+str(nv_accuracy)+" %")
# Out:
#       Draw  Loss  Win
# Draw    61    12   25
# Loss    34   125   10
# Win     52     5   93
# Accuracy of Decision Tree Model is: 0.6690647482014388 %
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# ## K Nearest Neighbor Classifier

# %%
from sklearnex import patch_sklearn
patch_sklearn()

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

k_range = list(range(1, 31))
param_grid = dict(n_neighbors=k_range)

grid_search = GridSearchCV(knn, param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameter (CV score=%0.3f):" % grid_search.best_score_)
print(grid_search.best_params_)

# Evaluate the model using cross-validation
scores = cross_val_score(grid_search.best_estimator_, X_train, y_train, cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# Print confusion matrix and accuracy on test set
clf = grid_search.best_estimator_
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

labels = [0.0,1.0,2.0]
cm = confusion_matrix(y_test, y_pred, labels=labels)
conf_mat = pd.DataFrame(cm,
                        columns=['Draw','Loss','Win'],
                        index=['Draw','Loss','Win'])

knn_accuracy = accuracy(y_test, y_pred)
print("Accuracy of KNN is: "+str(knn_accuracy)+" %")
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# Best parameter (CV score=0.493):
# {'n_neighbors': 1}
# Accuracy: 0.49 (+/- 0.09)
# Accuracy of KNN is: 0.3333333333333333 %

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearnex import patch_sklearn
patch_sklearn()

DTC = DecisionTreeClassifier(random_state=42)

param_grid = {'max_depth': [2, 4, 6, 8, 10]}

grid_search = GridSearchCV(DTC, param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameter (CV score=%0.3f):" % grid_search.best_score_)
print(grid_search.best_params_)

# Evaluate the model using cross-validation
scores = cross_val_score(grid_search.best_estimator_, X_train, y_train, cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# Print confusion matrix and accuracy on test set
clf = grid_search.best_estimator_
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

labels = [0.0,1.0,2.0]
cm = confusion_matrix(y_test, y_pred, labels=labels)
conf_mat = pd.DataFrame(cm,
                        columns=['Draw','Loss','Win'],
                        index=['Draw','Loss','Win'])

dt_accuracy = accuracy(y_test, y_pred)
print("Accuracy of Decision Tree Model is: "+str(dt_accuracy)+" %")
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# Best parameter (CV score=1.000):
# {'max_depth': 6}
# Accuracy: 1.00 (+/- 0.00)
# Accuracy of Decision Tree Model is: 1.0 %

# %% [markdown]
# ## Visualize the performance of each classifier and see which classifier performs the best.

# %%
scores = [dt_accuracy, nv_accuracy, knn_accuracy]
algorithms = ["Decision Tree","Naive Bayes","KNN"]

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str((scores[i]*100))+" %")
fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(algorithms, scores, align='center', color=['skyblue', 'orange', 'pink'])
ax.set_xlabel('Accuracy')
ax.set_ylabel('Algorithm')
ax.set_title('Comparison of Algorithm Accuracies')

# Add the score values to the plot
for i, v in enumerate(scores):
    ax.text(v + 0.01, i, str(round(v, 5)), color='black', fontweight='bold')

plt.show()
# Out:
# The accuracy score achieved using Decision Tree is: 100.0 %
# The accuracy score achieved using Naive Bayes is: 66.90647482014388 %
# The accuracy score achieved using KNN is: 33.33333333333333 %
